# %%
import pandas as pd
dataset = pd.read_csv('data/ruspini.csv')
print(dataset)
# Out:
#      #   X   Y  CLASS
# 0    1   4  53      1
# 1    2   5  63      1
# 2    3  10  59      1
# 3    4   9  77      1
# 4    5  13  49      1
# ..  ..  ..  ..    ...
# 70  71  66  23      4
# 71  72  61  25      4
# 72  73  76  27      4
# 73  74  72  31      4
# 74  75  64  30      4
#
# [75 rows x 4 columns]

# %%
rows, cols = dataset.shape
print('Jumlah baris', rows)
print('Jumlah Kolom', cols)
# Out:
# Jumlah baris 75
# Jumlah Kolom 4

# %%
data = pd.DataFrame(dataset, columns=['X', 'Y'])
print(data)
# Out:
#      X   Y
# 0    4  53
# 1    5  63
# 2   10  59
# 3    9  77
# 4   13  49
# ..  ..  ..
# 70  66  23
# 71  61  25
# 72  76  27
# 73  72  31
# 74  64  30
#
# [75 rows x 2 columns]

# %%
dataset.plot(x='X', y='Y', kind='scatter', c='CLASS', colormap='Paired')
# Out:
# <Axes: xlabel='X', ylabel='Y'>
